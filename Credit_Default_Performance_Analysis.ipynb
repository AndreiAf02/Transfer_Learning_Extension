# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreiAf02/Transfer_Learning_Extension/blob/main/Credit_Default_Performance_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pymc as pm
import seaborn as sns
import pandas as pd

# %%
path_to_data = 'https://raw.githubusercontent.com/AndreiAf02/Transfer_Learning_Extension/main/'

# %%
def perf_metrics(data, label):
    data_len = len(data)
    # print('Number of iterations:', data_len)
    mean = np.mean(data[label])
    var = np.var(data[label], ddof=1)
    var_mean = var/data_len

    se_mean = np.sqrt(var_mean)
    error_bound = 1.96*se_mean
    CI_low = mean - error_bound
    CI_high = mean + error_bound

    print('Error type:', label)
    print('Mean:', mean)
    print('Variance:', var)
    print('Variance of estimate:', var_mean)
    print('Standard error:', se_mean)
    print('95% Confidence Interval:  [', CI_low, ', ', CI_high, ']')
    print('-----------------------------')

# %% [markdown]
# Loading the performance data for the six sampling methods (plus original imbalanced data) collected from fine-tuning for heart disease prediction:

# %%
# data_orig = pd.read_csv(path_to_data + "Imbalanced_Fine_Tuning.csv", sep=",", header=0)
# data_SRS = pd.read_csv(path_to_data + "SRS_Fine_Tuning.csv", sep=",", header=0)
# data_SRSwR = pd.read_csv(path_to_data + "SRSwR_Fine_Tuning.csv", sep=",", header=0)
# data_Sy = pd.read_csv(path_to_data + "Sy_Fine_Tuning.csv", sep=",", header=0)
# data_Sym = pd.read_csv(path_to_data + "Sy_multi_Fine_Tuning.csv", sep=",", header=0)
# data_SRS_ROS = pd.read_csv(path_to_data + "SRS_ROS_Fine_Tuning.csv", sep=",", header=0)
# data_Sy_ROS = pd.read_csv(path_to_data + "Sy_ROS_Fine_Tuning.csv", sep=",", header=0)


data_orig = pd.read_csv(path_to_data + "Credit_Imbalanced_Fine_Tuning.csv", sep=",", header=0)
data_SRS = pd.read_csv(path_to_data + "Credit_SRS_Fine_Tuning.csv", sep=",", header=0)
data_SRSwR = pd.read_csv(path_to_data + "Credit_SRSwR_Fine_Tuning.csv", sep=",", header=0)
data_Sy = pd.read_csv(path_to_data + "Credit_Sy_Fine_Tuning.csv", sep=",", header=0)
data_Sym = pd.read_csv(path_to_data + "Credit_Sy_multi_Fine_Tuning.csv", sep=",", header=0)
data_SRS_ROS = pd.read_csv(path_to_data + "Credit_SRS_ROS_Fine_Tuning_Extended.csv", sep=",", header=0)
data_Sy_ROS = pd.read_csv(path_to_data + "Credit_Sy_ROS_Fine_Tuning_Extended.csv", sep=",", header=0)

# data_orig

# %% [markdown]
# Original (imbalanced) data performance:

# %%
data_orig
# Out:
#     Unnamed: 0       FPR       FNR
# 0            0  0.082037  0.656388
# 1            1  0.063649  0.700441
# 2            2  0.083451  0.656388
# 3            3  0.070721  0.682819
# 4            4  0.074965  0.674009
# 5            5  0.065064  0.704846
# 6            6  0.083451  0.669604
# 7            7  0.059406  0.709251
# 8            8  0.065064  0.696035
# 9            9  0.083451  0.656388
# 10          10  0.084866  0.656388
# 11          11  0.069307  0.682819
# 12          12  0.070721  0.678414
# 13          13  0.072136  0.674009
# 14          14  0.060820  0.709251
# 15          15  0.083451  0.656388
# 16          16  0.070721  0.678414
# 17          17  0.072136  0.674009
# 18          18  0.069307  0.696035
# 19          19  0.070721  0.674009
# 20          20  0.069307  0.691630
# 21          21  0.096181  0.643172
# 22          22  0.069307  0.691630
# 23          23  0.062235  0.709251
# 24          24  0.079208  0.674009
# 25          25  0.070721  0.674009
# 26          26  0.080622  0.660793
# 27          27  0.072136  0.674009
# 28          28  0.069307  0.691630
# 29          29  0.069307  0.691630
# 30          30  0.073550  0.691630
# 31          31  0.079208  0.669604
# 32          32  0.084866  0.656388
# 33          33  0.073550  0.674009
# 34          34  0.069307  0.691630
# 35          35  0.069307  0.691630
# 36          36  0.065064  0.696035
# 37          37  0.089109  0.647577
# 38          38  0.084866  0.656388
# 39          39  0.096181  0.647577
# 40          40  0.084866  0.660793
# 41          41  0.087694  0.647577
# 42          42  0.086280  0.647577
# 43          43  0.073550  0.691630
# 44          44  0.079208  0.669604
# 45          45  0.069307  0.691630
# 46          46  0.083451  0.669604
# 47          47  0.097595  0.643172
# 48          48  0.087694  0.656388
# 49          49  0.069307  0.691630

# %%
data = data_orig

orig_FPR = data['FPR']
orig_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.07595473833097593
# Variance: 8.919020074674772e-05
# Variance of estimate: 1.7838040149349545e-06
# Standard error: 0.0013355912604292356
# 95% Confidence Interval:  [ 0.07333697946053463 ,  0.07857249720141724 ]
# -----------------------------
# Error type: FNR
# Mean: 0.6755947136563876
# Variance: 0.0003594251067657166
# Variance of estimate: 7.188502135314333e-06
# Standard error: 0.0026811382163764576
# 95% Confidence Interval:  [ 0.6703396827522897 ,  0.6808497445604854 ]
# -----------------------------

# %% [markdown]
# ## Random Undersampling (RUS):
#
# SRS Random Undersampling performance:

# %%
data = data_SRS

SRS_FPR = data['FPR']
SRS_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.12384724186704378
# Variance: 8.995369662862601e-06
# Variance of estimate: 1.7990739325725203e-07
# Standard error: 0.0004241549165779551
# 95% Confidence Interval:  [ 0.123015898230551 ,  0.12467858550353657 ]
# -----------------------------
# Error type: FNR
# Mean: 0.5793832599118943
# Variance: 1.2863768807023911e-05
# Variance of estimate: 2.5727537614047824e-07
# Standard error: 0.0005072232015005605
# 95% Confidence Interval:  [ 0.5783891024369532 ,  0.5803774173868355 ]
# -----------------------------

# %% [markdown]
# SRSwR undersampling performance:

# %%
data = data_SRSwR

SRSwR_FPR = data['FPR']
SRSwR_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.10701555869872698
# Variance: 1.4176526208874352e-05
# Variance of estimate: 2.8353052417748707e-07
# Standard error: 0.0005324758437501997
# 95% Confidence Interval:  [ 0.10597190604497658 ,  0.10805921135247737 ]
# -----------------------------
# Error type: FNR
# Mean: 0.6120704845814977
# Variance: 4.54746900992152e-05
# Variance of estimate: 9.09493801984304e-07
# Standard error: 0.000953673844657755
# 95% Confidence Interval:  [ 0.6102012838459685 ,  0.6139396853170269 ]
# -----------------------------

# %% [markdown]
# Systematic Undersampling performance:

# %%
data = data_Sy

Sy_FPR = data['FPR']
Sy_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.1141442715700141
# Variance: 8.757746880374204e-06
# Variance of estimate: 1.7515493760748408e-07
# Standard error: 0.0004185151581573648
# 95% Confidence Interval:  [ 0.11332398186002567 ,  0.11496456128000253 ]
# -----------------------------
# Error type: FNR
# Mean: 0.5875770925110132
# Variance: 7.833908466839198e-06
# Variance of estimate: 1.5667816933678398e-07
# Standard error: 0.0003958259331281668
# 95% Confidence Interval:  [ 0.586801273682082 ,  0.5883529113399444 ]
# -----------------------------

# %% [markdown]
# Multiple Systematic undersampling performance:

# %%
data = data_Sym

Sym_FPR = data['FPR']
Sym_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.13267326732673262
# Variance: 9.145619119831324e-06
# Variance of estimate: 1.8291238239662649e-07
# Standard error: 0.0004276825720047831
# 95% Confidence Interval:  [ 0.13183500948560326 ,  0.133511525167862 ]
# -----------------------------
# Error type: FNR
# Mean: 0.579647577092511
# Variance: 2.8587033020042862e-05
# Variance of estimate: 5.717406604008573e-07
# Standard error: 0.0007561353452926647
# 95% Confidence Interval:  [ 0.5781655518157374 ,  0.5811296023692847 ]
# -----------------------------

# %% [markdown]
# ## Random Oversampling (ROS):
#
# SRS Oversampling performance:

# %%
data = data_SRS_ROS

SRS_ROS_FPR = data['FPR']
SRS_ROS_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.12489391796322483
# Variance: 4.100228167896603e-05
# Variance of estimate: 4.100228167896603e-07
# Standard error: 0.0006403302404147881
# 95% Confidence Interval:  [ 0.12363887069201185 ,  0.1261489652344378 ]
# -----------------------------
# Error type: FNR
# Mean: 0.5667400881057267
# Variance: 0.0001683370999678322
# Variance of estimate: 1.683370999678322e-06
# Standard error: 0.0012974478793686944
# 95% Confidence Interval:  [ 0.5641970902621641 ,  0.5692830859492893 ]
# -----------------------------

# %% [markdown]
# Systematic Resampling performance:

# %%
data = data_Sy_ROS

Sy_ROS_FPR = data['FPR']
Sy_ROS_FNR = data['FNR']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
# Out:
# Error type: FPR
# Mean: 0.121032531824611
# Variance: 2.1875495288465887e-05
# Variance of estimate: 2.1875495288465888e-07
# Standard error: 0.00046771246817319174
# 95% Confidence Interval:  [ 0.12011581538699155 ,  0.12194924826223046 ]
# -----------------------------
# Error type: FNR
# Mean: 0.5784140969162995
# Variance: 7.468580505123029e-05
# Variance of estimate: 7.468580505123029e-07
# Standard error: 0.0008642094945742628
# 95% Confidence Interval:  [ 0.576720246306934 ,  0.5801079475256651 ]
# -----------------------------

# %%
FPR = pd.DataFrame()

DF = FPR

DF['Orig'] = orig_FPR
DF['SRS_RUS'] = SRS_FPR
DF['SRSwR_RUS'] = SRSwR_FPR
DF['Sy_RUS'] = Sy_FPR
DF['Sy_m_RUS'] = Sym_FPR
DF['SRS_ROS'] = SRS_ROS_FPR
DF['Sy_ROS'] = Sy_ROS_FPR

# %%
dataset = FPR

plt.figure(figsize=(4,6), dpi=600)
plt.title('FPR')
sns.boxplot([dataset['Orig'], dataset['SRS_RUS'], dataset['SRSwR_RUS'],
             dataset['Sy_RUS'], dataset['Sy_m_RUS'], dataset['SRS_ROS'], dataset['Sy_ROS']], orient='h')
# Out:
# <Axes: title={'center': 'FPR'}>

# %%
FNR = pd.DataFrame()

DF = FNR

DF['Orig'] = orig_FNR
DF['SRS_RUS'] = SRS_FNR
DF['SRSwR_RUS'] = SRSwR_FNR
DF['Sy_RUS'] = Sy_FNR
DF['Sy_m_RUS'] = Sym_FNR
DF['SRS_ROS'] = SRS_ROS_FNR
DF['Sy_ROS'] = Sy_ROS_FNR

# %%
dataset = FNR

plt.figure(figsize=(4,6), dpi=600)
plt.title('FNR')
sns.boxplot([dataset['Orig'], dataset['SRS_RUS'], dataset['SRSwR_RUS'],
             dataset['Sy_RUS'], dataset['Sy_m_RUS'], dataset['SRS_ROS'], dataset['Sy_ROS']], orient='h')
# Out:
# <Axes: title={'center': 'FNR'}>

# %% [markdown]
# ## Transductive TL performance:

# %%
# data_orig = pd.read_csv(path_to_data + "Imbalanced_Extended.csv", sep=",", header=0)
# data_SRS = pd.read_csv(path_to_data + "SRS_RUS_Extended.csv", sep=",", header=0)
# data_SRSwR = pd.read_csv(path_to_data + "SRSwR_RUS_Extended.csv", sep=",", header=0)
# data_Sy = pd.read_csv(path_to_data + "Sy_RUS_Extended.csv", sep=",", header=0)
# data_Sy2 = pd.read_csv(path_to_data + "Sy2_RUS_Extended.csv", sep=",", header=0)
# data_SRS_ROS = pd.read_csv(path_to_data + "SRS_ROS_Extended.csv", sep=",", header=0)
# data_Sy_ROS = pd.read_csv(path_to_data + "Sy_ROS_Extended.csv", sep=",", header=0)

data_orig = pd.read_csv(path_to_data + "Credit_Imbalanced_Transductive.csv", sep=",", header=0)
data_SRS = pd.read_csv(path_to_data + "Credit_SRS_RUS.csv", sep=",", header=0)
data_SRSwR = pd.read_csv(path_to_data + "Credit_SRSwR_RUS.csv", sep=",", header=0)
data_Sy = pd.read_csv(path_to_data + "Credit_Sy_RUS.csv", sep=",", header=0)
data_Sy2 = pd.read_csv(path_to_data + "Credit_Sy2_RUS.csv", sep=",", header=0)
data_SRS_ROS = pd.read_csv(path_to_data + "Credit_SRS_ROS.csv", sep=",", header=0)
data_Sy_ROS = pd.read_csv(path_to_data + "Credit_Sy_ROS2.csv", sep=",", header=0)

data_SRS
# Out:
#     Unnamed: 0  Source time       FPR       TPR       FNR       TNR  \
# 0            0    14.256654  0.358272  0.641728  0.279743  0.720257
# 1            1    11.590063  0.228662  0.771338  0.363344  0.636656
# 2            2    10.458396  0.585880  0.414120  0.159164  0.840836
# 3            3    11.073127  0.293203  0.706797  0.344051  0.655949
# 4            4     9.190815  0.285827  0.714173  0.348875  0.651125
# 5            5    10.652092  0.268704  0.731296  0.352090  0.647910
# 15     0.692519
# 16     0.726824
# 17     1.927542
# 18     0.761900
# 19     1.260001
# 20     0.732383
# 21     0.771745
# 22     0.748068
# 23     0.750052
# 24     0.728114
# 25     0.750124
# 26     1.290919
# 27     0.752190
# 28     0.759853
# 29     0.764173
# 30     0.760933
# 31     1.138998
# 32     0.867874
# 33     1.329475
# 34     0.817291
# 35     1.102785
# 36     1.085878
# 37     1.122601
# 38     1.127373
# 39     0.805674
# 40     1.084284
# 41     1.084116
# 42     1.093924
# 43     1.064199
# 44     1.195867
# 45     3.063723
# 46     1.115113
# 47     1.341898
# 48     1.114075
# 49     0.875568

# %% [markdown]
# Original (imbalanced) dataset:

# %%
print('SRS RUS', len(data_SRS))
print('SRSwR RUS', len(data_SRSwR))
print('Sy RUS', len(data_Sy))
print('Sym RUS', len(data_Sy2))
print('SRS ROS', len(data_SRS_ROS))
print('Sy ROS', len(data_Sy_ROS))
# Out:
# SRS RUS 50
# SRSwR RUS 50
# Sy RUS 50
# Sym RUS 50
# SRS ROS 50
# Sy ROS 50

# %%
orig_FPR = data_orig['FPR']
orig_FNR = data_orig['FNR']
orig_time = data_orig['Source time']

# %%
data = data_orig

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.07596944151738667
# Variance: 0.00011912648739393944
# Variance of estimate: 2.3825297478787887e-06
# Standard error: 0.0015435445402963884
# 95% Confidence Interval:  [ 0.07294409421840575 ,  0.0789947888163676 ]
# -----------------------------
# Error type: FNR
# Mean: 0.5996945337620578
# Variance: 0.001033861808285519
# Variance of estimate: 2.0677236165710383e-05
# Standard error: 0.004547222906974143
# 95% Confidence Interval:  [ 0.5907819768643885 ,  0.6086070906597272 ]
# -----------------------------
# Error type: Source time
# Mean: 25.5948730745
# Variance: 9.52669298067965
# Variance of estimate: 0.190533859613593
# Standard error: 0.43650184376883566
# 95% Confidence Interval:  [ 24.739329460713083 ,  26.450416688286918 ]
# -----------------------------

# %% [markdown]
# ##Random Undersampling (RUS):
#
# SRS undersampling performance:

# %%
data = data_SRS

SRS_FPR = data['FPR']
SRS_FNR = data['FNR']
SRS_time = data['Source time']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.34508429926238143
# Variance: 0.010435405079496916
# Variance of estimate: 0.00020870810158993833
# Standard error: 0.014446733249767517
# 95% Confidence Interval:  [ 0.3167687020928371 ,  0.3733998964319258 ]
# -----------------------------
# Error type: FNR
# Mean: 0.30300643086816714
# Variance: 0.004109664311129276
# Variance of estimate: 8.219328622258551e-05
# Standard error: 0.009066051302666751
# 95% Confidence Interval:  [ 0.28523697031494033 ,  0.32077589142139395 ]
# -----------------------------
# Error type: Source time
# Mean: 14.432206240980008
# Variance: 4.493469235196709
# Variance of estimate: 0.08986938470393419
# Standard error: 0.2997822287993973
# 95% Confidence Interval:  [ 13.84463307253319 ,  15.019779409426826 ]
# -----------------------------

# %% [markdown]
# SRSwR Undersampling performance:

# %%
data = data_SRSwR

SRSwR_FPR = data['FPR']
SRSwR_FNR = data['FNR']
SRSwR_time = data['Source time']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.31789778714436245
# Variance: 0.012526691104844752
# Variance of estimate: 0.00025053382209689506
# Standard error: 0.015828260235948077
# 95% Confidence Interval:  [ 0.2868743970819042 ,  0.3489211772068207 ]
# -----------------------------
# Error type: FNR
# Mean: 0.32053054662379415
# Variance: 0.005712169644690206
# Variance of estimate: 0.00011424339289380412
# Standard error: 0.010688470091355644
# 95% Confidence Interval:  [ 0.2995811452447371 ,  0.3414799480028512 ]
# -----------------------------
# Error type: Source time
# Mean: 14.951323177339981
# Variance: 6.090586389168253
# Variance of estimate: 0.12181172778336506
# Standard error: 0.34901536897873864
# 95% Confidence Interval:  [ 14.267253054141653 ,  15.63539330053831 ]
# -----------------------------

# %% [markdown]
# Systematic Undersampling performance:

# %%
data = data_Sy

Sy_FPR = data['FPR']
Sy_FNR = data['FNR']
Sy_time = data['Source time']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.30486828240252895
# Variance: 0.009696237766304306
# Variance of estimate: 0.00019392475532608612
# Standard error: 0.013925686888842723
# 95% Confidence Interval:  [ 0.2775739361003972 ,  0.3321626287046607 ]
# -----------------------------
# Error type: FNR
# Mean: 0.32647909967845656
# Variance: 0.004211936172821089
# Variance of estimate: 8.423872345642179e-05
# Standard error: 0.009178165582316643
# 95% Confidence Interval:  [ 0.30848989513711594 ,  0.3444683042197972 ]
# -----------------------------
# Error type: Source time
# Mean: 14.478183472240007
# Variance: 1.3754894706224157
# Variance of estimate: 0.027509789412448315
# Standard error: 0.16586075308055342
# 95% Confidence Interval:  [ 14.153096396202121 ,  14.803270548277892 ]
# -----------------------------

# %% [markdown]
# Multiple Systematic Undersampling performance:

# %%
data_Sy2
# Out:
#     Unnamed: 0  Source time       FPR       TNR       FNR       TPR  \
# 0            0    18.672592  0.284773  0.715227  0.336817  0.663183
# 1            1    14.602922  0.461012  0.538988  0.230707  0.769293
# 2            2     9.910971  0.336143  0.663857  0.307074  0.692926
# 3            3    14.199039  0.311117  0.688883  0.323955  0.676045
# 4            4    13.106042  0.211538  0.788462  0.397910  0.602090
# 5            5    13.639891  0.244468  0.755532  0.378617  0.621383
# 6            6    12.891352  0.193361  0.806639  0.400322  0.599678
# 7            7    14.020450  0.204162  0.795838  0.398714  0.601286
# 8            8    12.622624  0.324552  0.675448  0.311093  0.688907
# 9            9    12.506262  0.277924  0.722076  0.341640  0.658360
# 10          10    13.646099  0.195732  0.804268  0.402733  0.597267
# 11          11    14.526071  0.459168  0.540832  0.242765  0.757235
# 12          12    12.511842  0.360116  0.639884  0.295016  0.704984
# 13          13    13.325007  0.161222  0.838778  0.436495  0.563505
# 14          14    13.863440  0.183614  0.816386  0.421222  0.578778
# 15          15    13.299897  0.252898  0.747102  0.353698  0.646302
# 16          16    13.422769  0.195469  0.804531  0.405949  0.594051


fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.302017913593256
# Variance: 0.008269954294013506
# Variance of estimate: 0.00016539908588027012
# Standard error: 0.012860757593558403
# 95% Confidence Interval:  [ 0.27681082870988155 ,  0.3272249984766305 ]
# -----------------------------
# Error type: FNR
# Mean: 0.33281350482315103
# Variance: 0.003572617822058777
# Variance of estimate: 7.145235644117555e-05
# Standard error: 0.00845294957048577
# 95% Confidence Interval:  [ 0.3162457236649989 ,  0.34938128598130314 ]
# -----------------------------
# Error type: Source time
# Mean: 14.886795832399995
# Variance: 2.4332111830425234
# Variance of estimate: 0.048664223660850464
# Standard error: 0.22059969098085896
# 95% Confidence Interval:  [ 14.454420438077511 ,  15.31917122672248 ]
# -----------------------------

# %% [markdown]
# ## Random Oversampling (ROS):
#
# SRS Oversampling performance:

# %%
data = data_SRS_ROS

SRS_ROS_FPR = data['FPR']
SRS_ROS_FNR = data['FNR']
SRS_ROS_time = data['Source time']

fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.3479399367755531
# Variance: 0.010491452912770337
# Variance of estimate: 0.00020982905825540674
# Standard error: 0.01448547749490526
# 95% Confidence Interval:  [ 0.3195484008855388 ,  0.37633147266556743 ]
# -----------------------------
# Error type: FNR
# Mean: 0.28763665594855303
# Variance: 0.003871056693890632
# Variance of estimate: 7.742113387781263e-05
# Standard error: 0.008798927995944315
# 95% Confidence Interval:  [ 0.2703907570765022 ,  0.3048825548206039 ]
# -----------------------------
# Error type: Source time
# Mean: 39.2443892983801
# Variance: 47.14567080843459
# Variance of estimate: 0.9429134161686917
# Standard error: 0.9710372887632543
# 95% Confidence Interval:  [ 37.34115621240412 ,  41.147622384356076 ]
# -----------------------------

# %% [markdown]
# Systematic Resampling performance:

# %%
data_Sy_ROS
# Out:
#     Unnamed: 0  Source time       FPR       TNR       FNR       TPR  \
# 0            0    36.825429  0.392518  0.607482  0.267685  0.732315
# 1            1    30.849988  0.257376  0.742624  0.340836  0.659164
# 2            2    34.695637  0.391201  0.608799  0.251608  0.748392
# 3            3    30.753816  0.272392  0.727608  0.329582  0.670418
# 4            4    29.860213  0.258693  0.741307  0.334405  0.665595
# 5            5    31.452419  0.288988  0.711012  0.319936  0.680064
# 6            6    28.114999  0.218651  0.781349  0.383441  0.616559
# 7            7    27.103901  0.450211  0.549789  0.224277  0.775723
# 8            8    30.785610  0.728135  0.271865  0.081994  0.918006
# 9            9    30.126736  0.203372  0.796628  0.380225  0.619775
# 10          10    34.285794  0.222076  0.777924  0.373794  0.626206
# 11          11    30.349740  0.353267  0.646733  0.292605  0.707395
# 12          12    38.367222  0.237355  0.762645  0.356913  0.643087
# 13          13    32.857453  0.242887  0.757113  0.356913  0.643087
# 14          14    30.304912  0.209958  0.790042  0.376206  0.623794
# 15          15    32.438412  0.434141  0.565859  0.238746  0.761254
# 16          16    32.129432  0.636459  0.363541  0.129421  0.870579


fig = plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.hist(data['FPR'], color='g', bins=30, label='FPR', alpha=0.5)
plt.title('False Positive Rate')

plt.subplot(1, 2, 2)
plt.hist(data['FNR'], color='r', bins=30, label='FNR', alpha=0.5)
plt.title('False Negative Rate')
# plt.show()

perf_metrics(data, 'FPR')
perf_metrics(data, 'FNR')
perf_metrics(data, 'Source time')
# Out:
# Error type: FPR
# Mean: 0.3218018967334036
# Variance: 0.013249981775208659
# Variance of estimate: 0.0002649996355041732
# Standard error: 0.01627880940069553
# 95% Confidence Interval:  [ 0.2898954303080403 ,  0.35370836315876686 ]
# -----------------------------
# Error type: FNR
# Mean: 0.30364951768488746
# Variance: 0.004833115879906207
# Variance of estimate: 9.666231759812414e-05
# Standard error: 0.009831699629165047
# 95% Confidence Interval:  [ 0.28437938641172394 ,  0.322919648958051 ]
# -----------------------------
# Error type: Source time
# Mean: 40.29579679641993
# Variance: 56.21369768194386
# Variance of estimate: 1.1242739536388773
# Standard error: 1.0603178550033368
# 95% Confidence Interval:  [ 38.21757380061339 ,  42.37401979222647 ]
# -----------------------------

# %%
FPR = pd.DataFrame()

DF = FPR

DF['Orig'] = orig_FPR
DF['SRS_RUS'] = SRS_FPR
DF['SRSwR_RUS'] = SRSwR_FPR
DF['Sy_RUS'] = Sy_FPR
DF['Sy_m_RUS'] = Sy2_FPR
DF['SRS_ROS'] = SRS_ROS_FPR
DF['Sy_ROS'] = Sy_ROS_FPR

# %%
dataset = FPR

plt.figure(figsize=(4,6), dpi=600)
plt.title('FPR')
sns.boxplot([dataset['Orig'], dataset['SRS_RUS'], dataset['SRSwR_RUS'],
             dataset['Sy_RUS'], dataset['Sy_m_RUS'], dataset['SRS_ROS'], dataset['Sy_ROS']], orient='h')
# Out:
# <Axes: title={'center': 'FPR'}>

# %%
FNR = pd.DataFrame()

DF = FNR

DF['Orig'] = orig_FNR
DF['SRS_RUS'] = SRS_FNR
DF['SRSwR_RUS'] = SRSwR_FNR
DF['Sy_RUS'] = Sy_FNR
DF['Sy_m_RUS'] = Sy2_FNR
DF['SRS_ROS'] = SRS_ROS_FNR
DF['Sy_ROS'] = Sy_ROS_FNR

# %%
dataset = FNR

plt.figure(figsize=(4,6), dpi=600)
plt.title('FNR')
sns.boxplot([dataset['Orig'], dataset['SRS_RUS'], dataset['SRSwR_RUS'],
             dataset['Sy_RUS'], dataset['Sy_m_RUS'], dataset['SRS_ROS'], dataset['Sy_ROS']], orient='h')
# Out:
# <Axes: title={'center': 'FNR'}>

# %%
Time = pd.DataFrame()

DF = FNR

DF['Orig'] = orig_time
DF['SRS_RUS'] = SRS_time
DF['SRSwR_RUS'] = SRSwR_time
DF['Sy_RUS'] = Sy_time
DF['Sy_m_RUS'] = Sy2_time
DF['SRS_ROS'] = SRS_ROS_time
DF['Sy_ROS'] = Sy_ROS_time

# %%
dataset = DF

plt.figure(figsize=(4,6), dpi=600)
plt.title('Training Time')
sns.boxplot([dataset['Orig'], dataset['SRS_RUS'], dataset['SRSwR_RUS'],
             dataset['Sy_RUS'], dataset['Sy_m_RUS'], dataset['SRS_ROS'], dataset['Sy_ROS']], orient='h')
# Out:
# <Axes: title={'center': 'Training Time'}>
